# %% [markdown]
# # UTILISATION DE LA BIBLIOTHEQUE SCIPY

# %% [markdown]
# ### C'est la reference en terme d'outils scientifiques python
# Il va notamment permettre de faire de :
# - L'Interpolation
# - l'Optimisation du problème
# - l'Interprétation du signal
# - la Transformee de fourrier
# - du Traitement d'image

# %% [markdown]
# ## Interpolation

# %% [markdown]
# Souvent il arrive qu'on ait a dispositon des donnees dans lesquels il manquent des valeurs. Et donc on remarque le nuage de points est techniquement mauvais a cause des valeurs manquantes . C'est la qu'intervient l'**Interpolation** ![Capture d’écran 2026-08-10 à 14.04.06.png](<attachment:Capture d’écran 2026-08-10 à 14.04.06.png>)
# Sur ce graphique par exemple, l'interpolatiion va permettre de placer plus de points entre ces differents points bleus

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 10)
y = x**2
plt.scatter(x, y)

# %%
import scipy as sp
from scipy. interpolate import interp1d
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import scipy as sp
#       2 from scipy. interpolate import interp1d
#
# ModuleNotFoundError: No module named 'scipy'
