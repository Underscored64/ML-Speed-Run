# %%
# Out:
# Index(['region_id', 'region_nom', 'prefecture', 'prefectu_1', 'commune_id',
#        'commune_no', 'canton_id', 'canton_nom', 'canton_n_1', 'grand_lome',
#        'Duplicata', 'canton_index', 'max_fsi', 'total_pop', 'min_rwi',
#        'urban_ratio', 'building_count', 'min_dist_basin', 'max_crop_prob',
#        'norm_fsi', 'norm_pop', 'norm_rwi', 'norm_urban', 'norm_build',
#        'norm_dist_basin', 'norm_crop', 'FRI', 'geometry'],
#       dtype='str')
